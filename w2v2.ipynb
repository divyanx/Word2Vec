# %%
corpus = ['king is a strong man', 
          'queen is a wise woman', 
          'boy is a young man',
          'girl is a young woman',
          'prince is a young king',
          'princess is a young queen',
          'man is strong', 
          'woman is pretty',
          'prince is a boy will be king',
          'princess is a girl will be queen']

# %%
import json
import string
import re
import gdown
corpus = []
# read json file
fileName = 'Electronics_5.json'

# read
with open(fileName, "r") as read_file:
    i = 0
    l = read_file.readline()
    while l and i < 100:
        i+=1
        l_dict = json.loads(l)
        review = l_dict["reviewText"]
        r_list = review.split('.')
        for r in r_list:
            r = re.sub('[^a-zA-Z]', ' ', r)
            r = r.lower()
            r = r.split()
            r = [w for w in r if not w in set(string.punctuation)]
            r = ' '.join(r)
            if r != '':
                corpus.append(r)
        l = read_file.readline()

# %%
print(corpus[:10])
# Out:
# ['we got this gps for my husband who is an otr over the road trucker', 'very impressed with the shipping time it arrived a few days earlier than expected', 'within a week of use however it started freezing up', 'could of just been a glitch in that unit', 'worked great when it worked will work great for the normal person as well but does have the trucker option', 'the big truck routes tells you when a scale is coming up ect', 'love the bigger screen the ease of use the ease of putting addresses into memory', 'nothing really bad to say about the unit with the exception of it freezing which is probably one in a million and that s just my luck', 'i contacted the seller and within minutes of my email i received a email back with instructions for an exchange very impressed all the way around', 'i m a professional otr truck driver and i bought a tnd at a truck stop hoping to make my life easier']

# %%
from nltk.corpus import stopwords
def remove_stop_words(corpus):
    stop_words = set(stopwords.words('english'))
    results = []
    for text in corpus:
        tmp = text.split(' ')
        for stop_word in stop_words:
            if stop_word in tmp:
                tmp.remove(stop_word)
        results.append(" ".join(tmp))
    
    return results

# %%
corpus = remove_stop_words(corpus)

# %%
words = []
for text in corpus:
    for word in text.split(' '):
        #print(word)
        words.append(word)

print(len(words))
words = set(words)
# Out:
# 4901

# %% [markdown]
# here we have word set by which we will have word vector

# %%
print(words)
# Out:
# {'', 'duty', 'variety', 'loose', 'liked', 'align', 'around', 'west', 'noble', 'poor', 'kidding', 'ledtv', 'fastener', 'reasonably', 'detail', 'residential', 'adjustable', 'arm', 'consideration', 'buying', 'crewed', 'freezing', 'directly', 'corner', 'hour', 'serves', 'friend', 'support', 'visible', 'model', 'alot', 'lg', 'must', 'another', 'design', 'atlas', 'slow', 'mil', 'movies', 'bubble', 'due', 'makes', 'weights', 'non', 'inherent', 'charging', 'overly', 'heart', 'impression', 'reminds', 'them', 'metric', 'that', 'notifications', 'stand', 'ok', 'tnd', 'hello', 'start', 'came', 'didn', 'ware', 'inches', 'products', 'negative', 'hd', 'many', 'markup', 'exactly', 'full', 'straightforward', 'hubit', 'found', 'took', 'risk', 'lots', 'other', 'ways', 'fast', 'preferred', 'take', 'connected', 'th', 'rated', 'happy', 'pro', 'parts', 'mins', 'replacement', 'today', 'video', 'routes', 'trouble', 'time', 'push', 'screws', 'restriction', 'extended', 'competitors', 'info', 'informed', 'rand', 'initially', 'hanging', 'deal', 'saw', 'needs', 'diy', 'challenging', 'somewhat', 'this', 'sometimes', 'pushes', 'mountinstalled', 'covers', 'line', 'to', 'tilted', 'misunderstood', 'house', 'studio', 'industry', 'mgmt', 'recommended', 'cost', 'respects', 'very', 'behind', 'excellent', 'believe', 'situations', 'fellas', 'detected', 'wider', 'condo', 'grab', 'instuction', 'high', 'mounting', 'programmed', 'perpendicular', 'lags', 'hz', 'routing', 'pickup', 'according', 'brick', 'considering', 'applied', 'connecting', 'paying', 'boards', 'flimsy', 'phillips', 'immediately', 'me', 'adjustments', 'program', 'lose', 'version', 'similar', 'pattern', 'corrected', 'centered', 'unusual', 'hollow', 'print', 'mind', 'use', 'v', 'bottom', 'yet', 'representative', 'needing', 'two', 'grafics', 'person', 'item', 'driver', 'built', 't', 'miles', 'x', 'live', 'trips', 'also', 'never', 'fairly', 'manufacturer', 'returning', 'finished', 'versions', 'a', 'went', 'navteq', 'wanted', 'random', 'tighten', 'bed', 'unfair', 'cool', 'site', 'all', 'determine', 'attachment', 'outdated', 'have', 'strictly', 'rooms', 'reviews', 'rearrange', 'different', 'appealing', 'returned', 'like', 'shipment', 'was', 'result', 'feet', 'theweight', 'using', 'results', 'performs', 'barnes', 'cable', 'extends', 'i', 'flummoxed', 'strongly', 'stores', 'screw', 'poi', 'balancing', 'hauling', 'unplug', 'center', 'tries', 'moderately', 'includes', 'supports', 'of', 'sites', 'magnificent', 'perfectlya', 'management', 'mounted', 'five', 'destroyed', 'noticed', 'office', 'decent', 'features', 'wayne', 'beat', 'looked', 'yes', 'assembly', 'sides', 'pleasing', 'cord', 'sturdier', 'could', 'happened', 'awesome', 'mount', 'overall', 'rotates', 'consider', 'oh', 'assure', 'fall', 'twice', 'couch', 'across', 'help', 'boiled', 'disagree', 'as', 'leadway', 'tilt', 'clips', 'length', 'sit', 'brain', 'stops', 'left', 'contact', 'reasons', 'needed', 'pc', 'pick', 'first', 'gave', 'easey', 'surface', 'set', 'fit', 'accomodates', 'compared', 'boring', 'achieve', 'exciting', 'your', 'solitude', 'fire', 'pointed', 'amongst', 'expected', 'playing', 'price', 'outstretched', 'thought', 'word', 'pricey', 'card', 'hinges', 'exchange', 'tools', 'part', 'plenty', 'judgement', 'varius', 'noted', 'information', 'e', 'totally', 'since', 'indeed', 'thats', 'messy', 'delivery', 'updated', 'extend', 'vesa', 'scenarios', 'minutes', 'straight', 'tag', 'stiff', 'contacted', 'type', 'drivers', 'sony', 'update', 'phoenix', 'for', 'monitor', 'etc', 'base', 'amazon', 'various', 'too', 'google', 'means', 'discard', 'upwards', 'lk', 'important', 'pay', 'shipped', 'imagine', 'formats', 'affix', 'compute', 'nuts', 'hte', 'phone', 'cents', 'nails', 'conjested', 'sd', 'treadmill', 'studfinders', 'perhaps', 'videos', 'whats', 'determining', 'earlier', 'deserves', 'simple', 'determines', 'says', 'televisions', 'months', 'mcnally', 'class', 'days', 'idea', 'cannot', 'tracking', 'depot', 'coming', 'perusing', 'gets', 'cheaper', 'local', 'prov ...

# %%
word2int = {}

for i,word in enumerate(words):
    word2int[word] = i

sentences = []
for sentence in corpus:
    sentences.append(sentence.split())
    
WINDOW_SIZE = 2

data = []
for sentence in sentences:
    for idx, word in enumerate(sentence):
        for neighbor in sentence[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(sentence)) + 1] : 
            if neighbor != word:
                data.append([word, neighbor])

# %%
import pandas as pd
for text in corpus:
    print(text)

df = pd.DataFrame(data, columns = ['input', 'label'])
# Out:
# got gps husband otr road trucker
# impressed shipping time arrived days earlier expected
# within week use however started freezing
# could glitch unit
# worked great worked work great normal person well the trucker option
# big truck routes tells scale coming ect
# love bigger screen the ease use the ease of putting addresses memory
# nothing really bad say unit the exception freezing probably one million luck
# contacted seller within minutes email i received email back instructions exchange impressed the way around
# professional otr truck driver i bought a tnd a truck stop hoping make life easier
# rand mcnally listening first thing charging connect it laptop install software and attempt to update it
# software detected problem update wanted my home address could sent a patch sd card
# hello think i unusual home address po box that a friend checks weekly that i might get check every six months
# live truck truck stops
# need make patch available sd card you send sd cards to the truck stops the devices sold
# ran update program multiple times the program said the tnd completely updated
# programmed height the length the weight rig and told i preferred highways
# parked truck stop cincinnati oh area
# next pickup miles freeway the side couple of blocks
# cell phone gps sprint said get freeway to get to my pickup
# tnd routed thru miles residential streets finally getting me pickup
# exciting especially since every time refused turn street posted trucks tnd took almost minutes to figure a route happened multiple times short trip
# decided give another chance
# pickup north side cincinnati of i needed head to phoenix az via i
# easy route hop drive west and south to intersection i
# indeed cell phone advised
# tnd however wanted route surface streets across the city pick the side the city
# turned next time i passed truck stop the chain i purchased it i returned it and got money back
# spent cheap printer
# take minute set route google print
# gotten lost yet several cross country trips
# well say
# unit truck four days
# prior garmin non truck gps
# one favorite features unit ability plan route determining mileage using the stop via feature
# would using map i would route several different ways forcing unit putting stops vias different locations along the route otherwise like gps determines what it thinks is the best route
# could add via stop points route based mileage and factors determine best route to take
# multiple stops ability route the important reason the garmin
# however truck specific
# considering hauling strictly hazmat i wanted something would take that consideration
# perusing various forums review sites word mouth choices boiled garmin the rand mcnally intelliroute tnd
# even though quite bit garmin chose the tnd several reasons
# main one the extra screen size ability coordinate the rand mcnally truck atlas and also its ease updating
# first impression tnd
# seems aesthetically pleasing durably built unit
# first thing noticed slow boot compared to old garmin
# whether unique tnd is common amongst truck specific gps units cannot tell really big deal
# second thing noticed the overwhelming wealth information put forth
# might explain manual available via the tnd dock well pages long
# somewhat learning curve unit
# next thing noticed the complexity entering routes
# previously mentioned like force preferred routing use stops vias
# big go unit
# enter multiple stops vias nowhere near user friendly as old garmin
# furthermore way determine total mileage route you chosen could the garmin
# totally flummoxed appeared omission one of best routing tools trucker could went online verified an expert source connected rand mcnally that feature a couple updates the line and was available point
# unbelievable
# also forcing unit follow specific route challenging
# unit price feature laden find this totally unacceptable
# still mulling selling unit buying garmin
# really like gps screen magnificent the volume is awesome
# another thing noticed i think unique unit is weird routing
# never owned truck specific gps playing one a couple days i get impression rand macnally the others that use navteq done take a plain old car specific navteq map and a road atlas with truck restrictions and made notifications the map
# databases thorough listing every road in country
# mean unit route roads you belong
# today coming home tried routing several ton county roads
# means that truck is limited unless road is posted tons
# county roads restriction listed rand mcnally road atlas believe that is not listed
# also unacceptable unit price sold truck specific
# however willing bet truck specific units the way one ever done truck specific version navteq
# another bone pick poi
# truck specific ones the others seem somewhat outdated
# think garmin least the ones i used current
# would also nice could add poi sto sum it i keep unit little longer see if i make it workable
# go back garmin
# like concept i like the unit point i say i somewhat unimpressed
# pros large screenterrific imagesoutstanding volumecons inability determine route mileage multiple stops viasa somewhat outdated poi information
# non truck specific routings
# cost
# going write long review even thought unit deserves one
# driven well mil miles done routing i pretty know whats fastest and shortest
# using basic garmin past three years gps unit get trouble you let
# really excited unit due size the features
# allot great grafics screen info thats usefull
# basic item lacking was the gps tracking
# gave unit allot leadway mistakes due fact allot of cool stuff that it its ability to track route you even close to the basic garmin could due
# like prossesor installed the tnd years old
# example needed make simple route change i
# e
# town next street due to the fact make the turn the street blocked would take the tnd upwards seconds to minute a half to reroute
# sitting stop light waiting directions waiting long cars backside make happy
# problem happened evertime reroute weather a simple street change a major highway change
# also time turned the unit would take twice long boot
# least dozen times a week put wrong roads made a wrong turn it got it self lost
#
# e
# take left xyz street ones drive way
# turn left yards turn less feet away
# might think conjested city situation might get a little mixed in country
# twice put bridges
# course made sure truck setting supposed
# also updated os version via rand mcnally
# all expected alot unit got unit of field tested people that drive allot
# many route mistakes
# going back basic garmin
# complaints three friends bought unit have the same complaints
# us returned units
# mine year got
# tries route non truck routes telling truck route illegal me
# bad problem even interstate denver colorado is listed according this gps a non truck route route city instead
# several drivers within company one half crashed un recoverable state
# company representative said rand mcnally informed that gps designed say long period time
# really truck driver gps
# one driver dollar ticket due gps routing wrong road
# companies response update the unit
# mine year i never noticed one update corrected functionality seem keep messing tools
# want gps routes i wanted tools i buy software computer
# suggestion nice garmen
# one rated cars actually routes better one rated for trucks
# wayne
# using nook hd
# works described
# hd picture samsung tv excellent
# cable wobbly sometimes disconnects
# price completely unfair works the nook hd and hd
# adaptor real easy setup use right box
# problem it well worth purchase
# recommend adaptor much viewing nook videos your hdtv
# disagree reviews length the adaptor i found fairly adequate to it connected to tv
# right long too short was able place nook right connection the tv stand it not fall or anything else it fine
# use judgement busy watching movies
# adapter easily connects nook hd my hdtv hdmi cable
# good traveling makes hotel tv potential smart tv long is accessible hdmi port
# also good sharing photos fb bigger screen
# bit pricey a good accessory
# sure note nook hd hd series
# work standard nook
# product really works great found following items need keep mind you must power adapter connected to work
# plugs the bottom
# appears it needs power nook power adapter operate
# plug fits loosely cannot move the nook around much without holding the adapter in place
# initial plugin seems need rock it around to get connection it seems solid
# works ft high quality hdmi cable put nook across the room with you
# tested cheap cables
# warning
# found lg smarttv years back work adapter does not seem work with many things
# bad software
# adapter works fine hdmi devices used like monitors i sure other tvs
# gave five stars it really nice extend screen use nook streaming server to your tv
# nice made device
# item described original description works without issues seen
# good product
# bought spare for nook hd fit perfectly
# satisfied price much less the bn site
# son crewed my hd charger cord needed another one exactly like one my son destroyed
# good beefy amp charger covers two outlets a power strip
# ok regular wall outlet
# best thing uses standard usb connector it charge a nook a kindle fire hd
# lost b n original cable
# looked around new one
# tried different cheaper model fit device properly back drawing board
# ordered one
# satisfied
# works exactly expected fits perfectly
# would recommend product anyone looking spare lieu original usb cable adapter
# charges a dead nook a hours
# lot heat compared wall worts
# dual charger port
# a total output
# run hot as
# use power raspberry pi to avoid needing a powered hubit job adequately designed to
# hot
# would always unplug using even though it cools amount of heat made
# nook hd runs hot right hold the left side portrait much charging
# guess better it plug
# go target barnes noble instead and pay still huge markup considering make thing cents
# worst option need one
# price gouging pure simple
# works well little pricey think a charging cable losing original would a lot cheaper replacement
# great buy compared a a retail store
# mount needed
# strong sturdy
# folds almost flat enable television to sit square flat the wall desired and extends and rotates angle turns
# perfect fit long as match correct visa pattern television
# great deal easy mount appears to fairly sturdy
# mounted tv it works great
# mount works really well get going
# problem arms little goofy getting the right spot
# really big issue considering different tv s mounting hole locations
# wall mount everything supposed
# piece attaches the wall overly long made easier to mount the arm the tight space needed to mount it in
# issues saw the joints tight initially moved the arm around install the joints loosened to the point i to take the included allen wrench and tighten up
# price cant beat item
# bought house i selling i could hang tv it worked great
# good quality price
# received mount well packaged shipping
# installation instructions moderately clear
# issues following little disjointed depending wall surface were installing on
# shipment mis cut piece missing screws
# contacted manufacturer shipped replacement part and screws the next day shipped texas normal mailing times applied i like the mount fits together and i easily mounted lbs tv
# part attaches the tv hook that hold the tv the arm till bolt on
# adjustable pushes almost flush wall
# happy took one star miscut piece
# took bit work used fit older vizio monitor to wall to use a compute monitor
# stable like ability move the tv to different angles
# vizio older the standard holes product fit and holds the tv stable
# used samsung
# fit feel great
# easy installation
# appears strong although personally spent way much tv risk leaving fully outstretched too little lag bolts long time it convenient to able to move it away the wall however i would feel very comfortable tilt swiveling needed
# movement fluid easily adjustable
# pleased purchase
# item serves purpose well as mount
# appealing attribute its large range motion
# using corner mount tv works perfectly to hide mount receptacles and cables behind the tv
# easy installation well
# love mount
# th one bought works great every time
# excellent seller excellent product
# glad buying
# heavy duty good quality price
# easy install
# holds inch sony ease
# make sure u mount ur lag screws heart the x ur mounting u problem u may have to make modificatoin two use ur brain and figure it till the house falls inch lag screws the way to go t be cheap go buy em
# much u pay tv
# nice quality still works great
# happy purchase
# need add words
# say wall mount i problems
# great bracket small tvs
# used lcd it worked well
# large mounting plate may block connections some tvs
# installed easily could adjusted make level
# links tight need loosened initial installation
# tv the desired position tighten
# bought tv for son
# mounted onto corner stud works great i love the angles it achieve
# fees sturdy well built
# works perfect application
# happy purchase
# using mount inch vizio tv great
# installation process quick easy and love the variety angles get mount
# side wall bedroom we pull tv and move it completely perpendicular the wall on it mounted we want to
# usually move quite perpendicular it works
# complaint joints little the stiff side
# takes quite bit force move tv one position to another
# little hard wife especially tv mounted ft the wall
# may possible loosen pivot points tried
# little nervous making less stable i
# overall great mount
# highly recommended
# installed sister philips lcd
# nice sturdy mount nuts bolts screws included
# problem since tv was small was using inner mounting hols the mount the outside edges the mount covered the cable connection and the power cable connection
# instead returning paying local store simply went a hardware store got a inch boring tool attaches to a hand drill drilled holes mount
# pretty easy bit messy
# visible mounting tv cares it is one thing consider buying may another mount not cover tv connections
# otherwise swivels well sag good value
# think would work well as it metal lighter guage thanwe expected it hardly deflected theweight the tv even extended straight
# heavy duty construction extends tilts perfectlya steal pricewill happy buy another needed
# well constructed wall mount tv sets inches
# mounting plate numerous holes varius sets
# plenty extra hardware provided
# price th would cost open market
# recommend highly
# used mount lcd tv to wall
# lbs
# installed less hour happy results
# pros comes hardware need comes with extra hardware of idea
# suspect universal hardware pack several models hardware used for all models it s nice a little extra is always better not enough included level is nice
# well cheap it works instructions decent enough job explaining install the unit
# cons metal tad flimsy side
# problems trusting lt lb television i mount something closer to maximum rated weight lbs i think i would quite bit nervous it holding
# holes the base little bit wide wall stud
# think particular stud i installing onto was typical x centered the left and right side holes a little far grab sides the stud
# reposition center holes aligned to the left side the stud that the right side holes were aligned to the right side of the stud
# result able install four six bolts to hold place i feel it issue lb television
# house uses wider studs probably even issue
# metal sag little bit the weight the television
# mounted base little bit level help compensate problems getting the television level using the adjustments available to
# conclusion all bad unit
# especially price
# yes would liked see sturdier unit take account lt price tag excellent bargain
# think i issue static mounting tv corner of the bedroom considering installing unit a television see a lot of traffic constant repositioning etc
# might want spend money something sturdier
# mount excellent
# well built sturdy
# used mount tv it fit need perfectly
# price also good much much cheaper inferior mount would cost retail store
# would definitely recommend
# works great much cheaper expensive versions the big box stores
# super easy install
# need drill a ratchet set get stud oh yea a stud finder
# bought tv gym gets moved around bit
# definitely sturdy works well
# tv
# price beat
# mine come screws the tv luckily leftover another mount i didn t want bother returning
# also sure mean tilt mine
# arm extends said tv swivels left right tilt and as expectation
# otherwise beat price target best buy etc
# going
# cannot beat deal anywhere else web retailers priced are getting couple pieces fabricated metal hold a tv articulates this mount reasonably priced
# pros easy install helps to cordless driver to drill pilot holes to drive lag screws
# also need stud finder
# well fabricated mount everything advertised
# e
# articulates made need loosen nuts con really stretching since good deal instructions could use some help novice diy ersinstall tip really helps you a second person assisting you for the final step mounting the flat panel to the tv mountinstalled a
# lbs inch flat panel lcd vesa mm x mm mount
# mount works beautifully originally tv sitting little high a stand the picture good the upward viewing angle of the screen inherent problem cheaper lcd not directly front of a lcd screen mount corrected this issue allowing tilt the screen
# would strongly recommend mount market
# mount easy install sturdy and is very functional and very affordable price
#
# works like charm lies flat wall want pulls and swivels like a charm when i need it too the instructions call it mounted a stud the wall however mine mounted directly into the drywall using heavy duty anchors and it works perfect well is a great product for amazing price
# easey put together install
# used mount led flat screen
# instuction say mount complete unit mount the tv to the back plate the ground first one person job
# well built product made china
# wish could buy american made better luck next time
# hung house great ease held my year old son i going put flat screen it to find it failed
# fully extends feet
# worth money
# wanted monitor the desk mounted the wall
# would rather vertical adjustment well price unit the job
# secure use concrete bolts thought since we putting outside wall made lath plaster concrete brick on outside
# one best features is one piece attaches the tv another that attaches to the wall
# piece the tv actually hooks onto the piece on the wall
# really happy purchase
# live studio condo i needed something rotate to see bed and my couch side the main room
# figure instructions use several varieties included to accommodate different scenarios tvs are pretty thorough
# afraid tighten specific joints loosen others to get want it
# originally bought different one careful didn t near amount of swing this one
# holds tv fine the articulation great
# use downstairs bedroom we move it seen bed the treadmill
# cable mgmt well
# another great buy amazon
# local stores wanted twice the money the mounts cheaply made
# mount made well get free hdmi cable and level
# know tv sit center the base placed
# held worked
# best mount ever found especially the price
# home depot nearly identical mount
# mount comes every fastener could need lags hollow wall anchors spacers varying lengths metric fasteners to tvs
# mount easy sturdy led tv one without issue
# also tvs i have used mount every led lcd tv i friends have mounted
# quality excellent
# instructions clear
# clear tilt feature was enough level it finished
# careful get wall bracket real vertical
# using inch computer screen i really need it level for reading
# everything needed plus lots extra hardware different situations
# process turning master bedroom fortress of solitude wife decided mount ourpanasonic tc l x inch p lcd hdtvon the wall the dresser to save space
# never enough dresser space displaying tchotchkes amirite fellas wife wanted fixed wall mount thought viewing angle required articulation
# hindsight fixed would worked
# unit highly rated price was right
# sold
# installation straightforward fairly simple
# point needed help balancing the tv i attached the arm otherwise it was
# think looks great wife says it reminds hospital
# sorry honey
# mount thepanasonic viera tc p inch p plasma hdtvin living room definitely use flat mount
# could spend four times much articulating tv mount see you would
# gave mount stars
# start box mounted the wall really liked daughter room
# ability move tv around play areas the room welcomed addition
# subtracted star tacky instructions poor cable management something moves maximum feet away the wall
# star fell tv mounted the mount seems sag even though two huge lag bolts stud mounting
# parts problem the problem the tv mounts the plate seems matter many washers use it not make full contact
# also move tv new position the mounts seems to want to fall direction hinges
# must releveled yanking it every time it moves
# otherwise works guess
# rather stationary mount i never have worry
# would set tv larger a
# trust
# price wall mount great
# hard install
# reason give star wire management
# could get little loop work
# big deal however
# overall highly recommend product
# well worth money
# needed corner mounted flatscreen
# job well easy install
# mount metal stud i used two support boards in back to distribute the weight evenly
# expectations item met fraction of cost competitors
# never bought one mainly due high prices the retail stores
# looked online much hadn t really needed monitor mounting device recently
# thing well built job
# fancy looking inexpensive way hang monitor tv pc wall the job
# comes nice bag heavy duty hardware
# primarily designed mounting tv sets get it work pc monitor long as it vesa mounting
# mainly articulates side side and
# pivot bit limited
# gave four stars only supporting tv
# think i would scared mount tv
# sprang bigger tv spend a little a properly rated mount
# tv mount make sure hitting wall studs with main screws use anchors drywall you re asking trouble
# lots hardware included kit mounting style brand of tv problem
# nothing fancy decent quality simple installation
# may mentioned one must discard provided phillips screws the manufacturer provides affix the bracket to the wall stud
# use
# tv mounted older flat panel it little heavier the news ones
# thing fazed stays put
# amazing easy move around mount able to hang one stud
# nice quality feel metal made
# sturdy
# arm stiff first work lose
# however mount works great make sure get stud just right
# impressed quality happy with the price
# anything really complain
# except seem way missing to tilt tv or ie
# mounted high wall pointed towards the chair
# quite savvy tools assembly etc
# difficult get to bolt heads the back the tv to adjust the angle
# reason buy though
# bought mount dell u monitor
# fits dell quite well bought it it reach the wall it s ability manipulate and it s weight capacity
# respects quite happy
# however noticeable tilt sag monitor the arm extended
# concerned sag perpendicular wall expected the rotational sag that i sometimes get
# mount plate the extender arms need screwed together and two holes arm to attach to the corner the plate
# holes align t put two screws
# used one screw secure attachment
# used zip ties secure arm better
# i install tv asap could wait replacement
# also mounting bracket attaches the wall larger screw hole the bottom
# means bottom wiggle the bracket misaligned
# quick fix
# gave stars actually stayed wall and holding tv albeit due my ingenuity and not the quality the mount
# quick fixes product like
# happy looks great happy got it
# holds good lil hard get it to wall
# fine love room room
# husband happy ordered cost us free shipping fast thankful seller
# willing pay simply mounting tv i bought item to give a shot
# real complaints
# holds tv wanted
# smooth pivot points planning moving it around lot use one if it going stay a static area this mount
# bought new could tell right away mine repackaged refurbished
# plus missing the arms random hardware included
# made mine work set serves it purpose
# wish seller upfront the condition could bought used one less
# rather good tv mount
# tv mount works exactly expected described
# would buy
# use hacksaw to cut away part to hang led tv my bedroom
# seems work fine
# hannspree lcd tv
# weighs
# lbs
# reviews said tv smaller a little skeptical got good price it said it could hold so lbs
# reservation was first time mounted tv worried it would fall within a week
# month nice it able to swing extend and angle
# like fact i get bigger tv still use mount living room
# hard install
# bought stud finder i one everything else i already install
# highly recommend recruiting help install least putting the tv
# would extremely hard especially bigger tv
# overall happy mount
# installed easy time finding stud the hardest part
# articulates well tv
# would hesitate look brand time for next tv mount
# two different rooms
# works well samsung tv size noted
# got one recently great wall mount
# unit pretty heavy need helper
# also includes variety screws mount also
# tv documentation stated x pattern
# putting hte plate back seems need the extra extenders x
# samsung series ledtv
# arm hard push pull is due to new and stiff
# make sure adjust tilt angle screws unit came loose tighten them
# initially scared mount it falls if i screw pretty easy
# use stud finder get general location the stud i also used nails to get the actual edges basic studfinders never exact
# make sure
# bad ish
# good product
# went easily
#
# wish i might gotten one little adjustment
# rigid
# purchased wall mounts hold and inch flat screens perfectly
# love highly recommend
# good item happy wit delivery time excellent i recomended good support led tv
# easy install it extra screws different sizes tv
# perfect led monitor mins problems
# included small bubble level it also came a hdmi cable expecting
# checked around amazon well as sites decided i needed
# read reviews looked the pictures bought two
# received today
# unpacked one read instructions immediately filled the return request amazon
# mounts very heavy require yes six screws mount to wall
# kidding tvs are lbs two screws the studs damage the wall necessary
# joke lag bolts ever heard screws issue hard move
# bought articulating wall mount reason i expect able to move without a wrench hand
# installed easily nice long reach
# attached tv grandkids works great
# accomodates many different size tv good price
# price
# beat
# two tv hanging living room
# issues easy hang
# would recommend friend
# works great
# holds inch tv effortlessly
# well built
# definitely worth price
# easy install tv to mount
# cord clips
# tv tilted sideways
# extends wall inches
# highly recommend brand
# used panasonic inch lcd
# durable works advertised
# advertised fitting televisions size the
# v mounting plate large covers plug connections the back of the television
# cut metal plate to get to the p
# c connector choose connect computer
# decided keep send back get something smaller mounting plate
# great product meets need a hanging television
# tv place put bed room
# mount use space poster hanging
# easy install came hard ware
# great mount many areas articulation
# great gift idea mother loves
# purchased two sturdy and give touch of class every room put them
# must video file want save space a bedroom or office
# perfect needed for
# move screen side side i need to i the tv sitting desk
# opportunity install the tv mount yet follow mounted place
# great price quick shipping
# pay best buy get the products fraction the prices
# videosecu long arm tv wall mount low profile full motion works great
# pro easy setup
# supports many different vesa formats
# articulation
# sturdy construction
# installed one person w much effort
# con cable guides fall easily
# joints bit stiff really man handle to get it fully extended you have to push fairly hard to get it to compact
# far noticed wear firm pulling pushing i worry attached studs buy bolts
# bought vizio worked perfectly
# would buy recommend it
# good quality
# impressed solid design tv wall mount
# think weights tv supporting
# also lots logical adjustments leveling tv difficult
# one semi negative takes fair amount force reposition the tv
# assure tv stays put plan move the tv the stand lot this may a negative
# overall pleased stand seems like good value
# bought uint tando
# get parts line i bought another fixed type
# well made strong mount problem the instructions very poorly written detailed
# pictures distinguish stud mount concrete
# also instructions tell the size the included boltsfor of you never worked the home building industry wall studs usually
# inches wide mount requires lag bolts middle holes secure to the wall to support lb tv
# four outboard holes the wall mount
# apart try use wall stud measuring
# wide
# helpful hint help install least wall mounts family friends i cannot say i expert suggestion drill pilot holes instructions tell to do
# comparing instructions unit others installed i still must say the pictures have lot detail
# complain back plate big the tv used fits perfect thelg lk inch p hz lcd hdtvi using it on
# works perfectly area the room using allows rearrange the room without the need to move the tv
# perhaps misunderstood install mount i installed the mount to the wall easy enough attach tv the mount screws difficult one person with one arm i held the tv heavy
# arm trying attach small screws connecting the tv to the mount
# took quite effort hold tv long
# certainly two people installing would waaaay easier another similar mount tv back plate the mount separate parts
# back plate installed slide the connecting parts together
# much easier
# took mins install tv wall mount inch samsung tv
# job much expensive arms does the trick
# used hang lcd i bought back heavy tv that outweighs my new
# everything seems made well easy to install tv hanging months brick wall it full reach
# imagine paying tv wall mounts well as one performs

# %%
df.head(10)
# Out:
#      input    label
# 0      got      gps
# 1      got  husband
# 2      gps      got
# 3      gps  husband
# 4      gps      otr
# 5  husband      got
# 6  husband      gps
# 7  husband      otr
# 8  husband     road
# 9      otr      gps

# %%
df.shape
# Out:
# (16112, 2)

# %%
len(word2int)
# Out:
# 1429

# %%
import tensorflow as tf
import numpy as np

ONE_HOT_DIM = len(words)


def to_one_hot_encoding(data_point_index):
    one_hot_encoding = np.zeros(ONE_HOT_DIM)
    one_hot_encoding[data_point_index] = 1
    return one_hot_encoding

X = [] 
Y = [] 
for x, y in zip(df['input'], df['label']):
    X.append(to_one_hot_encoding(word2int[ x ]))
    Y.append(to_one_hot_encoding(word2int[ y ]))


X_train = np.asarray(X)
Y_train = np.asarray(Y)



x = tf.Variable(tf.ones(shape=[1, ONE_HOT_DIM]), dtype=tf.float32)

y_label = tf.Variable(tf.ones(shape=[1, ONE_HOT_DIM]), dtype=tf.float32)

EMBEDDING_DIM = 50


W1 = tf.Variable(tf.random.normal([ONE_HOT_DIM, EMBEDDING_DIM]))
b1 = tf.Variable(tf.random.normal([1])) #bias
hidden_layer = tf.add(tf.matmul(x,W1), b1)


W2 = tf.Variable(tf.random.normal([EMBEDDING_DIM, ONE_HOT_DIM]))
b2 = tf.Variable(tf.random.normal([1]))
prediction = tf.nn.softmax(tf.add( tf.matmul(hidden_layer, W2), b2))


loss = lambda : tf.reduce_mean(-tf.reduce_sum(y_label * tf.math.log(prediction), axis=[1]))


# train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
train_op = tf.optimizers.SGD(learning_rate=0.05, name='SGD').minimize(loss, var_list=[W1, b1, W2, b2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-589058764938> in <module>
#      43
#      44 # train_op = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
# ---> 45 train_op = tf.optimizers.SGD(learning_rate=0.05, name='SGD').minimize(loss, var_list=[W1, b1, W2, b2])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in minimize(self, loss, var_list, grad_loss, name, tape)
#     496     grads_and_vars = self._compute_gradients(
#     497         loss, var_list=var_list, grad_loss=grad_loss, tape=tape)
# --> 498     return self.apply_gradients(grads_and_vars, name=name)
#     499
#     500   def _compute_gradients(self, loss, var_list, grad_loss=None, tape=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     596       RuntimeError: If called in a cross-replica context.
#     597     """
# --> 598     grads_and_vars = optimizer_utils.filter_empty_gradients(grads_and_vars)
#     599     var_list = [v for (_, v) in grads_and_vars]
#     600
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/optimizer_v2/utils.py in filter_empty_gradients(grads_and_vars)
#      76
#      77   if not filtered:
# ---> 78     raise ValueError("No gradients provided for any variable: %s." %
#      79                      ([v.name for _, v in grads_and_vars],))
#      80   if vars_with_empty_grads:
#
# ValueError: No gradients provided for any variable: ['Variable:0', 'Variable:0', 'Variable:0', 'Variable:0'].

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init) 

iteration = 20000
for i in range(iteration):

    sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
    if i % 3000 == 0:
        print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b7cc4cd09d36> in <module>
#       6 for i in range(iteration):
#       7
# ----> 8     sess.run(train_op, feed_dict={x: X_train, y_label: Y_train})
#       9     if i % 3000 == 0:
#      10         print('iteration '+str(i)+' loss is : ', sess.run(loss, feed_dict={x: X_train, y_label: Y_train}))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     965
#     966     try:
# --> 967       result = self._run(None, fetches, feed_dict, options_ptr,
#     968                          run_metadata_ptr)
#     969       if run_metadata:
#
# KeyboardInterrupt:

# %%
vectors = sess.run(W1 + b1)
print(vectors)
# Out:
# [[ 0.939799   -0.07269198 -0.97047895 ...  0.7051742  -0.15360045
#    0.51146656]
#  [-0.1873407  -1.1416229   0.5282674  ...  0.16597298  0.7074446
#   -0.72289747]
#  [ 1.52764     0.25991395 -0.7446072  ...  1.1543721   1.399253
#   -0.36812222]
#  ...
#  [-0.43489447 -0.7359016  -0.1985785  ...  0.23103496 -0.19230562
#    0.49056885]
#  [ 1.794864    2.3677323  -0.14232966 ... -0.20893413  0.12733576
#    1.1365646 ]
#  [-1.3320976  -1.1418248  -1.0579894  ...  0.19501397 -0.72448903
#    0.29870006]]

# %%
w2v_df = pd.DataFrame(vectors, columns = ['x'+str(i) for i in range(1, EMBEDDING_DIM+1)])
w2v_df['word'] = words
w2v_df = w2v_df[['word'] + ['x'+str(i) for i in range(1, EMBEDDING_DIM+1)]]
w2v_df
# Out:
#          word        x1        x2        x3        x4        x5        x6  \
# 0        days  0.939799 -0.072692 -0.970479  0.764277  0.005084  0.117511
# 1      glitch -0.187341 -1.141623  0.528267  0.468640 -1.393529  0.200473
# 2        unit  1.527640  0.259914 -0.744607 -1.541466  1.504610  0.358284
# 3        love  1.088039  0.799649 -0.056783 -0.642312  0.689861  0.118699
# 4    exchange  0.041626  0.385806 -0.161574  1.478175 -0.883460  0.212744
# ..        ...       ...       ...       ...       ...       ...       ...
# 60         of  0.869975 -0.539592  1.452256  1.815241  0.302172  1.918517
# 61  impressed  0.326595 -0.304986  2.031691 -0.350441 -1.221668  0.026647
# 62     coming -0.434894 -0.735902 -0.198579  0.900158  1.309612  0.546925
# 63       well  1.794864  2.367732 -0.142330  0.735045  0.674124 -0.099631
# 64       time -1.332098 -1.141825 -1.057989 -0.560103  0.154454  0.128888
#
#           x7        x8        x9  ...       x41       x42       x43       x44  \
# 0  -0.822014  0.656016  0.222889  ...  0.246136 -0.994582  1.446947 -0.132918
# 1   0.410444  0.088482 -1.088427  ... -0.402051  1.283518 -0.739742  0.616822
# 2  -0.055283  0.531721  0.011619  ... -0.790788 -0.022923  0.614775  0.558936
# 3  -0.260751  1.538907 -0.531299  ... -0.385175  1.642984 -0.324092  1.695246
# 4  -0.285856  0.071793  1.351103  ... -2.041175  1.338348  0.501510 -1.734342
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 60 -1.295815 -0.315433  0.311235  ... -0.060091 -1.204293 -0.887394  0.324741
# 61  0.948178  0.335767  0.458206  ... -0.501210 -0.162042 -0.170697 -1.744612
# 62  1.014227  0.202772  0.718133  ...  0.642574 -0.287559 -0.582734 -0.065121
# 63  0.088953  0.732747  1.582632  ... -0.045020 -0.176293 -0.606731 -1.478055
# 64 -1.479478 -0.951743  1.372131  ... -1.297017 -0.216625 -0.355595  0.526917
#
#          x45       x46       x47       x48       x49       x50
# 0   1.080357  1.574163  1.063431  0.705174 -0.153600  0.511467
# 1   0.633267  1.597046  1.230733  0.165973  0.707445 -0.722897
# 2   0.518648 -0.755605  0.235046  1.154372  1.399253 -0.368122
# 3   0.725493 -0.499327  0.758729  0.740417 -0.460985  1.670823
# 4   0.717494 -0.605008  0.322809  0.563093 -0.080149 -0.035231
# ..       ...       ...       ...       ...       ...       ...
# 60  0.756478 -0.259807 -0.073089 -0.940413  0.499771  0.622067
# 61  0.302444  1.170005  0.598283 -2.103957  0.710737 -0.583350
# 62  0.664541 -1.016463  0.321847  0.231035 -0.192306  0.490569
# 63  0.294860 -0.703321  0.895588 -0.208934  0.127336  1.136565
# 64  0.948271  0.763656  0.207428  0.195014 -0.724489  0.298700
#
# [65 rows x 51 columns]

# %%
# import matplotlib.pyplot as plt

# fig, ax = plt.subplots()

# for word, x1, x2 in zip(w2v_df['word'], w2v_df['x1'], w2v_df['x2']):
#     ax.annotate(word, (x1,x2 ))
    
# PADDING = 1.0
# x_axis_min = np.amin(vectors, axis=0)[0] - PADDING
# y_axis_min = np.amin(vectors, axis=0)[1] - PADDING
# x_axis_max = np.amax(vectors, axis=0)[0] + PADDING
# y_axis_max = np.amax(vectors, axis=0)[1] + PADDING
 
# plt.xlim(x_axis_min,x_axis_max)
# plt.ylim(y_axis_min,y_axis_max)
# plt.rcParams["figure.figsize"] = (10,10)

# plt.show()

# %%
# save model to csv
w2v_df.to_csv('w2v_model.csv', index=False)

# %%
def cosine_similarity(x1, x2):
    return np.dot(x1, x2) / (np.linalg.norm(x1) * np.linalg.norm(x2))

# %%
def findSimilarity(word, model, n = 10):
    # get the index of the word
  
    word_vec = list(w2v_df[w2v_df['word'] == word].values[0])[1:]
    similarities = []
    for index, row in w2v_df.iterrows():
        if row['word'] == word:
            continue
        similarities.append((row['word'], cosine_similarity(word_vec, list(row)[1:])))
    similarities = sorted(similarities, key=lambda x: x[1], reverse=True)
    return similarities[:n]

# %%
print(findSimilarity('bigger', w2v_df, n=10))
# Out:
# [('well', 0.33368500147873625), ('got', 0.31847343848889964), ('ease', 0.2768834139469381), ('love', 0.22028789144405328), ('coming', 0.21684597084694407), ('option', 0.20082822510856896), ('contacted', 0.19742697251107186), ('person', 0.18055928692072787), ('instructions', 0.1761952300034511), ('nothing', 0.17218533851667098)]

# %%
# find the row where word column is 'love'
# Out:
# [1.0880392789840698,
#  0.799649178981781,
#  -0.056783244013786316,
#  -0.6423118710517883,
#  0.6898607015609741,
#  0.11869940906763077,
#  -0.2607506513595581,
#  1.5389068126678467,
#  -0.5312985777854919,
#  -1.1486507654190063,
#  -2.397254228591919,
#  -0.12846669554710388,
#  1.529862642288208,
#  2.1785366535186768,
#  0.4197899401187897,
#  0.725969135761261,
#  1.2426855564117432,
#  -2.1740548610687256,
#  1.2013800144195557,
#  1.6401646137237549,
#  -0.08999241143465042,
#  -0.8410106897354126,
#  0.7160742282867432,
#  0.3351263999938965,
#  0.13558551669120789,
#  1.3662101030349731,
#  1.1011170148849487,
#  0.4691050052642822,
#  0.7881497144699097,
#  0.5187317132949829,
#  0.7334776520729065,
#  0.18310797214508057,
#  -1.2190450429916382,
#  -0.6486284136772156,
#  0.8288964629173279,
#  0.4706714451313019,
#  1.9058754444122314,
#  0.18385061621665955,
#  -0.659069299697876,
#  -0.0752599835395813,
#  -0.38517534732818604,
#  1.6429835557937622,
#  -0.32409191131591797,
#  1.6952455043792725,
#  0.7254928946495056,
#  -0.4993272125720978,
#  0.7587293982505798,
#  0.74041748046875,
#  -0.46098509430885315,
#  1.6708232164382935]
